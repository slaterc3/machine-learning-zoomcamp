# %%
import numpy as np

# %%
A = np.array([[1,2], [3,2]])
b = np.array([-2,6])

np.linalg.solve(A, b)
# Out:
# array([ 4., -3.])

# %%
A = np.array([[2,4], [3,3]])
b = np.array([22,15])

np.linalg.solve(A, b)
# Out:
# array([-1.,  6.])

# %%
A = np.array([[1,-3,-6], [0, 1, 2], [-4,12,21]])
b  = np.array([4, -2, -4])
np.linalg.solve(A, b)
# Out:
# array([-2.,  6., -4.])

# %%
A = np.array([
    [0, 2, 4],
    [1, 3, 3],
    [2, 7, 6]
])
b = np.array([4, 5, 10])

np.linalg.solve(A, b)
# Out:
# array([2., 0., 1.])

# %%
A = np.array([
    [3, 12, 42],
    [1, 2, 8],
    [2, 5, 16]
])

b = np.array([-27, -5, -6])

np.linalg.solve(A, b)
# Out:
# array([ 3.,  4., -2.])

# %%
A = np.array([
    [4, 8, 4],
    [4, 6, 0],
    [3, 3, -1]
])

b = np.array([20, 4, 1])

np.linalg.solve(A, b)
# Out:
# array([ 4., -2.,  5.])

# %%
A = np.array([
    [2, -8, 0],
    [-7, 2, -5],
    [3, 0, 2]
])
b = np.array([18, -6, 1])

np.linalg.solve(A, b)
# Out:
# array([ 1., -2., -1.])

# %%
A = np.array([
    [-1, 3, -5, -8],
    [4, -8, 4, 4],
    [3, 5, -16, 1],
    [-1, 1, -3, -1]]
)
b = np.array([2, -44, 18, 6])

np.linalg.solve(A, b)
# Out:
# array([-3.00000000e+00,  5.00000000e+00, -1.34039121e-16,  2.00000000e+00])

# %%
A = np.array([
    [-1, 6, 4, 0],
    [4, -22, -2, 2],
    [1, -6, -5, 3],
    [0, -3, -22, 0]
])
b = np.array([-22, 0, 5, 6])
np.linalg.solve(A, b)
# Out:
# array([ 1.17814166e+18,  2.15992638e+17, -2.94535416e+16, -9.81784719e+15])

# %%
A = np.array([
    [2, 2, -8],
    [-3, -5, 6],
    [5, -1, -38]
])
b = np.array([4, -4, 16])
np.linalg.solve(A, b)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[13], line 7
#       1 A = np.array([
#       2     [2, 2, -8],
#       3     [-3, -5, 6],
#       4     [5, -1, -38]
#       5 ])
#       6 b = np.array([4, -4, 16])
# ----> 7 np.linalg.solve(A, b)
#
# File c:\Users\slate\OneDrive\Documents\0000000WGU_MSDA\ml-zoomcamp\machine-learning-zoomcamp\.venv\Lib\site-packages\numpy\linalg\_linalg.py:471, in solve(a, b)
#     468 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     469 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     470               over='ignore', divide='ignore', under='ignore'):
# --> 471     r = gufunc(a, b, signature=signature)
#     473 return wrap(r.astype(result_t, copy=False))
#
# ...

# %%
A = np.array([
    [1, 1, -1, 2],
    [4, 2, -6, 2],
    [-3, 1, 7, 6],
    [-1, -1, 4, 3] 
])
b = np.array([7, 16, 3, 8])
np.linalg.solve(A, b)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[14], line 8
#       1 A = np.array([
#       2     [1, 1, -1, 2],
#       3     [4, 2, -6, 2],
#       4     [-3, 1, 7, 6],
#       5     [-1, -1, 4, 3]
#       6 ])
#       7 b = np.array([7, 16, 3, 8])
# ----> 8 np.linalg.solve(A, b)
#
# File c:\Users\slate\OneDrive\Documents\0000000WGU_MSDA\ml-zoomcamp\machine-learning-zoomcamp\.venv\Lib\site-packages\numpy\linalg\_linalg.py:471, in solve(a, b)
#     468 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     469 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     470               over='ignore', divide='ignore', under='ignore'):
# --> 471     r = gufunc(a, b, signature=signature)
#     473 return wrap(r.astype(result_t, copy=False))
#
# ...
