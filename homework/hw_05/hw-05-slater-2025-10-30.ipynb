# %% [markdown]
# ### HW #5

# %% [markdown]
# #### Question #1 what is uv version?
# uv 0.9.6 (265224465 2025-10-29)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Question #2 : scikit-learn hash
#
# ### sha256:0108521f7c740b3c6396b931e9c201d4b12df0f0a51e6b363579d1502c3132e0
